# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 第一題

# %%
L = [0,5,0,5,0]

# %%
plot(L)

# %% [markdown]
# ## 第二題

# %% [markdown]
# 最高溫

# %%
max = [19.1, 19.6, 22.1, 25.7, 29.2, 32, 34.3, 33.8, 31.1, 27.5, 24.2, 20.7]

# %%
plot(max)

# %% [markdown]
# 最低溫

# %%
min = [13.9, 14.2, 15.8, 19, 22.3, 24.6, 26.3, 26.1, 24.8, 22.3, 19.3, 15.6]

# %%
plot(min)

# %% [markdown]
# ## 挑戰題一：買相機

# %%
a = 100000
b = 150000
c = 230000
d = 80000

# %%
plot([a,a+b,a+b+c,a+b+c+d])

# %%
pie([a,b,c,d], labels=["fIRST","SECOND","THIRD","FOURTH"])
# Out:
# ([<matplotlib.patches.Wedge at 0x24683723b38>,
# ...
#   <matplotlib.text.Text at 0x2468373e860>])
