# %% [markdown]
# ## 項目價格 (單位k)

# %%
# %pylab inline
item1 = 100
item2 = 150
item3 = 230
item4 = 80
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 圓餅圖
# 查詢指令 >> pie?

# %%
pie([item1, item2, item3, item4], labels=['1', '2', '3', '4'])
# Out:
# ([<matplotlib.patches.Wedge at 0x26d25e38588>,
# ...
#   <matplotlib.text.Text at 0x26d25e502b0>])

# %% [markdown]
# ## 累積折線圖 (k)

# %%
plot([1, 2, 3, 4], [item1, item1 + item2, item1 + item2 + item3, item1 + item2 + item3 + item4])
