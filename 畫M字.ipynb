# %% [markdown]
# ## 斜腳M

# %%
m = [0,5, 1, 5,0]
# %pylab inline
plot(m)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 正M

# %%
plot([0,0,1,2,2],[0,5,1,5,0])
