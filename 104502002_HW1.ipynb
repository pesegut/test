# %% [markdown]
# # 第一題

# %%
plot([1,1,3,5,5],[1,3,2,3,1])

# %% [markdown]
# # 第二題

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 最高溫分布圖

# %%
plot([19.1,19.6,22.1,25.7,29.2,32.0,34.3,33.8,31.1,27.5,24.2,20.7])

# %% [markdown]
# ## 最低溫分布圖

# %%
plot([13.9,14.2,15.8,19.0,22.3,24.6,26.3,26.1,24.8,22.3,19.3,15.6])
